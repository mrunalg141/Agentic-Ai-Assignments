# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
age=25

# %%
print(age)
# Out:
# 25

# %%
def sum(a,b):
    return a+b

# %%
a=10
b=80

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %%
print{result}
# Out:
#   Cell In[7], line 1
#     print{result}
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
return result
# Out:
#   Cell In[8], line 1
#     return result
#     ^
# SyntaxError: 'return' outside function

# %%
name="Mrunal"

# %%
weight=70.5

# %%
print(type(weight))
# Out:
# <class 'float'>

# %%
num=1+2j

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
pi=9.89

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
pi_exp=3.14e2

# %%
print(type(pi_exp))
# Out:
# <class 'float'>

# %%
address='''pcmc'''

# %%
print(type(address))
# Out:
# <class 'str'>

# %%
age=10
weight=70.6
num=1+2j
eligible_for_voting=True
name="rajesh"

# %%
print(age,weight,num,eligible_for_voting,name)
# Out:
# 10 70.6 (1+2j) True rajesh

# %%
age,weight,num,eligible_for_voting,name=10,70.6,1+2j,True,"rajesh"

# %%
print(age,weight,num,eligible_for_voting,name)
# Out:
# 10 70.6 (1+2j) True rajesh

# %%
##Arithmetic Operators

a=10
b=10
print(id(a))
# Out:
# 140729546528152

# %%
c=a+b
print(c)
# Out:
# 20

# %%
print(id(c))
# Out:
# 140729546528472

# %%
##Subtraction
p=2
r=3
e=r-p
print(e)
# Out:
# 1

# %%
##Division

x=20
y=2
z=x/y

# %%
print(z)
# Out:
# 10.0

# %%
##Multiplication
m=3
b=4
n=b*m
print(n)
# Out:
# 12

# %%
print(10-2+9)
# Out:
# 17

# %%
print(2*3+5-2)
# Out:
# 9

# %%
print(10**2+7-4)
# Out:
# 103

# %%
x=int(3.8)

# %%
print(x)
# Out:
# 3

# %%
y=int("10")

# %%
print(y)
# Out:
# 10

# %%
z=int(True)

# %%
print(z)
# Out:
# 1

# %%
z=int(False)

# %%
print(z)
# Out:
# 0

# %%
x=float(4)

# %%
print(x)
# Out:
# 4.0

# %%
x=complex(3)

# %%
print(x)
# Out:
# (3+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
x=bool(1)

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("Hello")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(10.1)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0+0j)
# Out:
# False

# %%
bool(0+1j)
# Out:
# True
