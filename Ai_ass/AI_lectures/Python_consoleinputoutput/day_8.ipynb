# %% [markdown]
# ## CONSOLE INPUT OUTPUT

# %% [markdown]
# ### Input-print()- It displays output to the console screen

# %%
print(10)
# Out:
# 10

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(10.5)
# Out:
# 10.5

# %%
print(1+2j)
# Out:
# (1+2j)

# %%
print(type(1+2J))
# Out:
# <class 'complex'>

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(10.3)
# Out:
# 10.3

# %%
print(type(10.3))
# Out:
# <class 'float'>

# %%
print(id(3445))
# Out:
# 2659049327888

# %%
print(True)
# Out:
# True

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
name="mrunal"

# %%
print("My name is",name)
# Out:
# My name is mrunal

# %%
height=5.5

# %%
weight=60

# %%
print("height",height,"weight",weight)
# Out:
# height 5.5 weight 60

# %%
name="mrunal"

# %%
print(name,end="\n")
print(height,end="\n")
print(weight,end="\n")
print("program executed successfully")
# Out:
# mrunal
# 5.5
# 60
# program executed successfully

# %% [markdown]
# # input-input()

# %%
age=input("Enter your age:")

# %%
print(age)
# Out:
# 56

# %%
name=input("Enter your name:")

# %%
print(name)
# Out:
# mrunal

# %%
input_value=input("Enter a value:")
print(type(input_value))
# Out:
# <class 'str'>

# %% [markdown]
# # accepting two values and return its addition

# %%
num1=input("Enter first number:")

# %%
num2=input("Enter second number:")

# %%
num3=num1+num2

# %%
print(num3)
# Out:
# 367

# %% [markdown]
# ## Memory address and value printing

# %%
num1=10

# %%
print(num1)
# Out:
# 10

# %%
print(id(num1))
# Out:
# 140711303075224
