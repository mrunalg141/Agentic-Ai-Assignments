# %% [markdown]
# ## Formatted Output

# %% [markdown]
# ## 1.string concatenation

# %%
name="rahul"
age=25
print("Name :" ,name,"age :",age)
# Out:
# Name : rahul age : 25

# %%
Roll_no=101
address="pune"

# %%
print("my address is : ",address,"and my roll number is : ",Roll_no)
# Out:
# my address is :  pune and my roll number is :  101

# %%
"my address is " + " and my roll_no is"
# Out:
# 'my address is  and my roll_no is'

# %%
a="hello"
b="world"
c=" "
d=a+c+b
print(d)
# Out:
# hello world

# %% [markdown]
# ## Format() method

# %%
Roll_no=101
address="pune"
print("my address is {} and my roll number is {}".format(address,Roll_no))
# Out:
# my address is pune and my roll number is 101

# %% [markdown]
# # f-string method()

# %%
roolno=101
address="pune"
pincode=411033
print("my roll number is {rollno} and my address is {address} and my pincode is {pincode}".format(rollno=roolno, address=address, pincode=pincode))
# Out:
# my roll number is 101 and my address is pune and my pincode is 411033
