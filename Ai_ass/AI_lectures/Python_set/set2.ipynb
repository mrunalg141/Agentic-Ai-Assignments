# %% [markdown]
# # Built in functions in sets
#
# # 1.len()

# %%
set1={10,20,30}

# %%
print(set1)

# %% [markdown]
# ## 2) max()

# %%
print(max(set1))

# %% [markdown]
# ## 3) min()

# %%
print(min(set1))

# %% [markdown]
# ## 4) sum()

# %%
print(sum(set1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(sum(set1))
#
# NameError: name 'set1' is not defined

# %% [markdown]
# ## any()

# %%
set2={10,20,30,false}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 set2={10,20,30,false}
#
# NameError: name 'false' is not defined

# %%
print(any(set2))

# %% [markdown]
# ## all()

# %%
set3={10,20,30,40,0}

# %%
print(all(set3))
# Out:
# False

# %% [markdown]
# ## 7) sorted

# %%
set4={40,30,20,10}

# %%
print(sorted(set4))
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ## set methods

# %% [markdown]
# ## add()

# %%
data={10,20,30,40}

# %%
data.add(50)

# %%
print(data)
# Out:
# {40, 10, 50, 20, 30}

# %% [markdown]
# ## update()

# %%
set1={30,40,50}

# %%
set2={70,60}

# %%
set1.update(set2)

# %%
print(set1)
# Out:
# {50, 70, 40, 60, 30}

# %%
set3={20,"mrunal"}

# %%
print(update.set3())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(update.set3())
#
# NameError: name 'update' is not defined

# %%
set1.update(set2,set3)

# %%
print(set1)
# Out:
# {50, 20, 70, 40, 'mrunal', 60, 30}

# %% [markdown]
# ## copy()

# %%
data={3,4,5,6,7,7,}

# %%
data_copy=data.copy()

# %%
print(data)
# Out:
# {3, 4, 5, 6, 7}

# %%
print(id(data))
# Out:
# 3014353497760

# %%
set1={10,20,30}

# %%
set2={10,30,40}

# %%
set3=set1.copy()

# %%
print(set3)
# Out:
# {10, 20, 30}

# %%
print(id(set3))
# Out:
# 3014353499776

# %%
print(set1 is set3)
# Out:
# False

# %% [markdown]
# ## remove()

# %%
data={3,4,5,6,7,8,10}

# %%
data.remove(10)

# %%
print(data)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
data.remove(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data.remove(100)
#
# KeyError: 100

# %% [markdown]
# ## discard()

# %%
set2={10,20,30,}

# %%
set2.discard(30)

# %%
print(set2)
# Out:
# {10, 20}

# %%
set2.discard(33)

# %%
print(set2)
# Out:
# {10, 20}

# %% [markdown]
# ## clear()

# %%
set5={2,3,4,4,5}

# %%
set5.clear()

# %%
print(set5)
# Out:
# set()
