# %% [markdown]
# ## String is a collection of unicode characters

# %%
str1='Jai Ganesh'

# %%
str2="Jai Ganesh"

# %%
str3='''Jai Ganesh'''

# %%
str4=""""Jai Ganesh"""

# %%
print(str1)
print(str2)
print(str3)
print(str4)
# Out:
# Jai Ganesh
# Jai Ganesh
# Jai Ganesh
# "Jai Ganesh

# %% [markdown]
# ## String Escape Characters

# %%
str5='let's play cricket'
# Out:
#   Cell In[6], line 1
#     str5='let's play cricket'
#                             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str5='let/s play cricket'

# %%
str5="let's play cricket"

# %% [markdown]
# ## Multi-line Strings

# %%
text="my name is mrunal\
i live in pune\
i love painting"

# %% [markdown]
# # above is blackslach

# %%
text="""my name is mrunal
i live in pune
i love painting"""

# %% [markdown]
#     # Triple quotes

# %% [markdown]
# # String indexing

# %% [markdown]
# # Jai Ganesh
# # 0123456789

# %%
str1="Jai Ganesh"

# %%
print(str1(0))
print(str1(1))
print(str1(2))
print(str1(3))
print(str1(4))
print(str1(5))
print(str1(6))
print(str1(7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(str1(0))
#       2 print(str1(1))
#       3 print(str1(2))
#       4 print(str1(3))
#
# TypeError: 'str' object is not callable

# %%
print(str1(0))
print(str1(1))
print(str1(2))
print(str1(3))
print(str1(4))
print(str1(5))
print(str1(6))
print(str1(7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(str1(0))
#       2 print(str1(1))
#       3 print(str1(2))
#       4 print(str1(3))
#
# TypeError: 'str' object is not callable

# %%
print(str1[0])
print(str1[1])
print(str1[2])
print(str1[3])
print(str1[4])
# Out:
# J
# a
# i
#
# G

# %% [markdown]
# # Negative Backtracking

# %%
print(str1[-10])
print(str1[-9])
print(str1[-8])
print(str1[-8])
print(str1[-7])
# Out:
# J
# a
# i
# i

# %% [markdown]
# # String Indexing

# %% [markdown]
# # Indexing allows acessing individual characters by position

# %% [markdown]
# # string[Start : Stop : end ]

# %% [markdown]
# # Slicing

# %%
print(str1[1:6])
# Out:
# ai Ga
