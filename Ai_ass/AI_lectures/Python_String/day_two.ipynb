# %% [markdown]
# # Immutability
# ## Once string created it cannot be changed
# ## Strings are immutable

# %%
str1="Hello"

# %%
print(str1)
# Out:
# Hello

# %%
print(type(str1))
# Out:
# <class 'str'>

# %%
print(str1[0])
# Out:
# H

# %%
print(str1[6:11])

# %%
str1="India"

# %% [markdown]
# # Concatanation
# ## + operator combines two or more strings

# %%
greeting="Hello"
name="Rahul"
message = greeting + name

# %%
print(message)
# Out:
# HelloRahul

# %%
print(type(message))
# Out:
# <class 'str'>

# %%
space=" "

# %%
messsage1=greeting+space+name

# %%
print(messsage1)
# Out:
# Hello Rahul

# %%
message2="welcome"+"to"+"python"

# %%
print(message2)
# Out:
# welcometopython

# %% [markdown]
# ## Repetition

# %%
Word="Hi "

# %%
repeated_word=Word*4

# %%
print(repeated_word)
# Out:
# Hi Hi Hi Hi

# %%
word="Hi"
word1=word+" "
repeaded_word=word1*3
print(repeaded_word)
# Out:
# Hi Hi Hi

# %% [markdown]
# ## Membership testing(in/not in)
# # checks if there is substring or not

# %%
text="python programming"
print("python" in text)
# Out:
# True

# %%
print("java" in text)
# Out:
# False

# %%
print("python" not in text)
# Out:
# False

# %%
print("java" not in text)
# Out:
# True

# %%
name="tina"

# %% [markdown]
# ## Built-in String Functions

# %% [markdown]
# # 1.len()
# ## returns the length of the string

# %%
greeting1="helloworld"

# %%
print(len(greeting1))
# Out:
# 10

# %% [markdown]
# ## min()

# %%
name="riya"

# %%
print(min(name))
# Out:
# a

# %% [markdown]
# ## max()

# %%
name="rina"

# %%
print(max(name))
# Out:
# r

# %%
nme="lina"

# %%
print(ord("n"))
# Out:
# 110

# %% [markdown]
# ## Separator
