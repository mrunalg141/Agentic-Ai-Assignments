# %% [markdown]
# ## String Methods

# %% [markdown]
# ## Syntax
# String_variable_name.method_name()
#
# ## 1) str1.upper()

# %%
str1="city"

# %%
print(str1.upper())
# Out:
# CITY

# %%
print(str1.lower())
# Out:
# city

# %% [markdown]
# ## CONTENT TEST METHODS

# %% [markdown]
# ## 1) isalpha()- It checks if all characters are alphabets

# %%
greetings="hello"
print(greetings.isalpha())
# Out:
# True

# %%
greeting="hello1"
print(greeting.isalpha())
# Out:
# False

# %% [markdown]
# ## 2) isdigit(): checks if all characters are digits

# %%
str2="1234"

# %%
print(str2.isdigit())
# Out:
# True

# %%
str3="helo123"
print(str3.isdigit())
# Out:
# False

# %% [markdown]
# ## 3) isalnum()-checks if all characters are alphabets or digits

# %%
str4="hello234"

# %%
print(str4.isalnum())
# Out:
# True

# %% [markdown]
# ## 4) islower()-checks if all characters are uppercase

# %%
str5="okay"

# %%
print(str5.islower())
# Out:
# True

# %% [markdown]
# ## 5) isupper()- checks if all the characters are uppercase

# %%
str6="hello"

# %%
print(str6.isupper())
# Out:
# False

# %% [markdown]
# ## 6) startswith()-checks if string starts with value

# %%
str7="hello world"

# %%
print(str7.startswith("h"))
# Out:
# True

# %% [markdown]
# ## 7) endswith()-checks if string ends with value

# %%
str8="hello"

# %%
print(str8.endswith("d"))
# Out:
# False

# %% [markdown]
# ## SEARCH METHODS

# %% [markdown]
# ## 1) find()-Its returns the  lowest index os substring/value/word that we provideas a parameter to the method

# %%
str9="hello world"

# %%
print(str9.find("hello"))
# Out:
# 0

# %%
text="hello i live in pune "

# %%
text.find("pune")
# Out:
# 16

# %% [markdown]
# # replace()
# ## replaces old string with new string

# %%
new_text=text.replace("pune","mumbai")

# %%
print(new_text)
# Out:
# hello i live in mumbai

# %% [markdown]
# # Trim whitespace method

# %% [markdown]
# # lstrip()
# # rstrip()
# # strip()

# %%
str6="hello world  ."

# %%
print(str6.lstrip())
# Out:
# hello world  .

# %%
print(str6.strip())
# Out:
# hello world  .

# %% [markdown]
# # Split()

# %%
str1="Hello welcome to python string"

# %%
print(str1.split())
# Out:
# ['Hello', 'welcome', 'to', 'python', 'string']

# %%
new_text=text.split()

# %%
str1.partition("-")
# Out:
# ('Hello welcome to python string', '', '')

# %%
str6="HELLO"

# %%
print(str6.lower())
# Out:
# hello

# %%
print(str6.upper())
# Out:
# HELLO

# %% [markdown]
# # capitalize()

# %%
print(str6.capitalize())
# Out:
# Hello

# %% [markdown]
# # title()

# %%
print(str6.title())
# Out:
# Hello

# %% [markdown]
# # swapcase()

# %%
print(str6.swapcase())
# Out:
# hello

# %% [markdown]
# # str()

# %%
str(10)
# Out:
# '10'

# %%
str('50.6')
# Out:
# '50.6'

# %%
str(2+7j)
# Out:
# '(2+7j)'

# %% [markdown]
# # crd()

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %% [markdown]
# # joint()
# ## joints elements of iterable( list/tipple) into a single string

# %%
str7="he llo"

# %%
print(str7.joint())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(str7.joint())
#
# AttributeError: 'str' object has no attribute 'joint'
