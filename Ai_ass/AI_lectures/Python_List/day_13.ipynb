# %% [markdown]
# # List

# %%
list1=["apple","mango","banana"]

# %% [markdown]
# # immutability concept

# %%
age=25

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(id(age))
# Out:
# 140711303075704

# %% [markdown]
# # Hetrogenous list

# %%
student=["mrunal",25,"pune"]

# %%
print(student)
# Out:
# ['mrunal', 25, 'pune']

# %%
print(type(student))
# Out:
# <class 'list'>

# %%
def sum():
    a=10
    b=20
    c=a+b
    print(c)

# %% [markdown]
# ## Duplicates are allowed

# %%
marks =[10,20,30,30,40,50]

# %%
print(marks)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ## How to create empty list

# %%
empty_list=[]

# %%
print(empty_list)
# Out:
# []
